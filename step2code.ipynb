# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# housekeeping
#get_ipython().magic('reset -sf')
plt.close('all')

# getting data
riverNodes = pd.read_csv('riverNodes.csv', sep=",", decimal = ".")
distances = pd.read_csv('distances.csv', sep=",", decimal=".")
#renaming danish words
new_column_name = 'Vandmaengd'
distances = distances.rename(columns={distances.columns[12]: new_column_name})
new_column_name2 = 'Bygvaerkst'
distances = distances.rename(columns={distances.columns[7]: new_column_name2})
# removing unnecessary data
riverNodes.rename(columns={"vandfoering": "water flow (m^3/s)"}, inplace=True)
distances.rename(columns={"BI-5 (kg)": "Biological oxygen demand, 5 days (kg)"}, inplace=True)

# %%
riverNodes.head(5)
# Out:
#                X             Y  ogc_fid  objectid  water flow (m^3/s)  \
# 0  705580.000000  6.190940e+06     1112   6710652            0.019918
# 1  706015.395437  6.190953e+06     1113   6710653            0.028163
# 2  706468.191344  6.190940e+06     1114   6710654            0.037356
# 3  706918.242455  6.190888e+06     1115   6710655            0.042151
# 4  707249.877164  6.190780e+06     1116   6710656            0.047416
#
#                           beregningspunktlokalid         registreringfra  \
# 0             Novana_Model_MOELLEAA_DK1_-11928.0  2020/11/13 14:09:44+01
# 1  Novana_Model_MOELLEAA_DK1_-11474.666666666666  2020/11/13 14:09:44+01
# 2  Novana_Model_MOELLEAA_DK1_-11021.333333333334  2020/11/13 14:09:44+01
# 3             Novana_Model_MOELLEAA_DK1_-10568.0  2020/11/13 14:09:44+01
# 4             Novana_Model_MOELLEAA_DK1_-10214.0  2020/11/13 14:09:44+01
#
#    registreringtil   aar maaned
# 0              NaN  1993  marts
# 1              NaN  1993  marts
# 2              NaN  1993  marts
# 3              NaN  1993  marts
# 4              NaN  1993  marts

# %%
riverNodes['beregningspunktlokalid'].unique()
# Out:
# array(['Novana_Model_MOELLEAA_DK1_-11928.0',
#        'Novana_Model_MOELLEAA_DK1_-11474.666666666666',
#        'Novana_Model_MOELLEAA_DK1_-11021.333333333334',
#        'Novana_Model_MOELLEAA_DK1_-10568.0',
#        'Novana_Model_MOELLEAA_DK1_-10214.0',
#        'Novana_Model_MOELLEAA_DK1_-9860.0',
#        'Novana_Model_MOELLEAA_DK1_-9506.0',
#        'Novana_Model_MOELLEAA_DK1_-9218.5',
#        'Novana_Model_MOELLEAA_DK1_-8931.0',
#        'Novana_Model_MOELLEAA_DK1_-8931.0_Downstream',
#        'Novana_Model_MOELLEAA_DK1_-8536.25',
#        'Novana_Model_MOELLEAA_DK1_-8141.5',
#        'Novana_Model_MOELLEAA_DK1_-7746.75',
#        'Novana_Model_MOELLEAA_DK1_-7352.0',
#        'Novana_Model_MOELLEAA_DK1_-7168.0',
#        'Novana_Model_MOELLEAA_DK1_-7167.0',
#        'Novana_Model_MOELLEAA_DK1_-7087.0',
#        'Novana_Model_MOELLEAA_DK1_-7007.0',
#        'Novana_Model_MOELLEAA_DK1_-6912.0',
#        'Novana_Model_MOELLEAA_DK1_-6817.0',
#        'Novana_Model_MOELLEAA_DK1_-6692.0',
#        'Novana_Model_MOELLEAA_DK1_-6567.0',
#        'Novana_Model_MOELLEAA_DK1_-6437.0',
#        'Novana_Model_MOELLEAA_DK1_-6307.0',
#        'Novana_Model_MOELLEAA_DK1_-6167.0',
#        'Novana_Model_MOELLEAA_DK1_-6027.0',
#        'Novana_Model_MOELLEAA_DK1_-5874.5',
#        'Novana_Model_MOELLEAA_DK1_-5722.0',
#        'Novana_Model_MOELLEAA_DK1_-5567.0',
#        'Novana_Model_MOELLEAA_DK1_-5412.0',
#        'Novana_Model_MOELLEAA_DK1_-5302.0',
#        'Novana_Model_MOELLEAA_DK1_-5192.0',
#        'Novana_Model_MOELLEAA_DK1_-5084.5',
#        'Novana_Model_MOELLEAA_DK1_-4977.0',
#        'Novana_Model_MOELLEAA_DK1_-4889.5',
#        'Novana_Model_MOELLEAA_DK1_-4802.0',
#        'Novana_Model_MOELLEAA_DK1_-4764.5',
#        'Novana_Model_MOELLEAA_DK1_-4727.0',
#        'Novana_Model_MOELLEAA_DK1_-4542.0',
#        'Novana_Model_MOELLEAA_DK1_-4427.0',
#        'Novana_Model_MOELLEAA_DK1_-4358.0',
#        'Novana_Model_MOELLEAA_DK1_-4357.0',
#        'Novana_Model_MOELLEAA_DK1_-4247.0',
#        'Novana_Model_MOELLEAA_DK1_-4137.0',
#        'Novana_Model_MOELLEAA_DK1_-3974.5',
#        'Novana_Model_MOELLEAA_DK1_-3812.0',
#        'Novana_Model_MOELLEAA_DK1_-3657.0',
#        'Novana_Model_MOELLEAA_DK1_-3502.0',
#        'Novana_Model_MOELLEAA_DK1_-3332.0',
#        'Novana_Model_MOELLEAA_DK1_-3162.0',
#        'Novana_Model_MOELLEAA_DK1_-2966.0',
#        'Novana_Model_MOELLEAA_DK1_-2858.262898097279',
#        'Novana_Model_MOELLEAA_DK1_-2858.262898097279_Downstream',
#        'Novana_Model_MOELLEAA_DK1_-2771.0',
#        'Novana_Model_MOELLEAA_DK1_-2770.0',
#        'Novana_Model_MOELLEAA_DK1_-2767.0',
#        'Novana_Model_MOELLEAA_DK1_-2592.0',
#        'Novana_Model_MOELLEAA_DK1_-2417.0',
#        'Novana_Model_MOELLEAA_DK1_-2232.0',
#        'Novana_Model_MOELLEAA_DK1_-2047.0',
#        'Novana_Model_MOELLEAA_DK1_-1872.0',
#        'Novana_Model_MOELLEAA_DK1_-1697.0',
#        'Novana_Model_MOELLEAA_DK1_-1454.5',
#        'Novana_Model_MOELLEAA_DK1_-1212.0',
#        'Novana_Model_MOELLEAA_DK1_-977.0',
#        'Novana_Model_MOELLEAA_DK1_-742.0',
#        'Novana_Model_MOELLEAA_DK1_-554.5',
#        'Novana_Model_MOELLEAA_DK1_-367.6995755784792',
#        'Novana_Model_MOELLEAA_DK1_-367.0',
#        'Novana_Model_MOELLEAA_DK1_-367.0_Downstream',
#        'Novana_Model_MOELLEAA_DK1_-100.0',
#        'Novana_Model_MOELLEAA_DK1_-7.0',
#        'Novana_Model_MOELLEAA_DK1_248.0',
#        'Novana_Model_MOELLEAA_DK1_503.0',
#        'Novana_Model_MOELLEAA_DK1_839.0',
#        'Novana_Model_MOELLEAA_DK1_1175.0',
#        'Novana_Model_MOELLEAA_DK1_1511.0',
#        'Novana_Model_MOELLEAA_DK1_1852.5',
#        'Novana_Model_MOELLEAA_DK1_2194.0',
#        'Novana_Model_MOELLEAA_DK1_2194.0_Downstream',
#        'Novana_Model_MOELLEAA_DK1_2270.0',
#        'Novana_Model_MOELLEAA_DK1_2392.0',
#        'Novana_Model_MOELLEAA_DK1_2393.0',
#        'Novana_Model_MOELLEAA_DK1_2483.0',
#        'Novana_Model_MOELLEAA_DK1_2573.0',
#        'Novana_Model_MOELLEAA_DK1_2638.0',
#        'Novana_Model_MOELLEAA_DK1_2703.0',
#        'Novana_Model_MOELLEAA_DK1_2790.5',
#        'Novana_Model_MOELLEAA_DK1_2878.0',
#        'Novana_Model_MOELLEAA_DK1_3138.0',
#        'Novana_Model_MOELLEAA_DK1_3398.0',
#        'Novana_Model_MOELLEAA_DK1_3525.5',
#        'Novana_Model_MOELLEAA_DK1_3653.0',
#        'Novana_Model_MOELLEAA_DK1_3670.0',
#        'Novana_Model_MOELLEAA_DK1_3687.0',
#        'Novana_Model_MOELLEAA_DK1_3819.0',
#        'Novana_Model_MOELLEAA_DK1_3951.0',
#        'Novana_Model_MOELLEAA_DK1_4083.0',
#        'Novana_Model_MOELLEAA_DK1_4216.0',
#        'Novana_Model_MOELLEAA_DK1_4657.0',
#        'Novana_Model_MOELLEAA_DK1_5098.0',
#        'Novana_Model_MOELLEAA_DK1_5238.0',
#        'Novana_Model_MOELLEAA_DK1_5316.0',
#        'Novana_Model_MOELLEAA_DK1_5450.0',
#        'Novana_Model_MOELLEAA_DK1_5798.0',
#        'Novana_Model_MOELLEAA_DK1_6146.0',
#        'Novana_Model_MOELLEAA_DK1_6418.0',
#        'Novana_Model_MOELLEAA_DK1_6580.0',
#        'Novana_Model_MOELLEAA_DK1_6679.0',
#        'Novana_Model_MOELLEAA_DK1_6969.0',
#        'Novana_Model_MOELLEAA_DK1_7124.0',
#        'Novana_Model_MOELLEAA_DK1_7442.0',
#        'Novana_Model_MOELLEAA_DK1_7545.0',
#        'Novana_Model_MOELLEAA_DK1_7828.0',
#        'Novana_Model_MOELLEAA_DK1_8070.0',
#        'Novana_Model_MOELLEAA_DK1_8227.0',
#        'Novana_Model_MOELLEAA_DK1_8300.0',
#        'Novana_Model_MOELLEAA_DK1_8413.0',
#        'Novana_Model_MOELLEAA_DK1_8738.0',
#        'Novana_Model_MOELLEAA_DK1_9063.0',
#        'Novana_Model_MOELLEAA_DK1_9374.0',
#        'Novana_Model_MOELLEAA_DK1_9685.0',
#        'Novana_Model_MOELLEAA_DK1_10023.0',
#        'Novana_Model_MOELLEAA_DK1_10361.0',
#        'Novana_Model_MOELLEAA_DK1_10836.0',
#        'Novana_Model_MOELLEAA_DK1_10912.0',
#        'Novana_Model_MOELLEAA_DK1_11013.0',
#        'Novana_Model_MOELLEAA_DK1_11180.0',
#        'Novana_Model_MOELLEAA_DK1_11337.0',
#        'Novana_Model_MOELLEAA_DK1_11375.0',
#        'Novana_Model_MOELLEAA_DK1_11690.0',
#        'Novana_Model_MOELLEAA_DK1_11801.0',
#        'Novana_Model_MOELLEAA_DK1_12219.0',
#        'Novana_Model_MOELLEAA_DK1_12637.0',
#        'Novana_Model_MOELLEAA_DK1_12929.0',
#        'Novana_Model_MOELLEAA_DK1_13221.0',
#        'Novana_Model_MOELLEAA_DK1_13304.0',
#        'Novana_Model_MOELLEAA_DK1_13500.0',
#        'Novana_Model_KIGHANERENDEN_DK1_0.0',
#        'Novana_Model_KIGHANERENDEN_DK1_424.0',
#        'Novana_Model_KIGHANERENDEN_DK1_848.0',
#        'Novana_Model_KIGHANERENDEN_DK1_1272.0',
#        'Novana_Model_KIGHANERENDEN_DK1_1666.5',
#        'Novana_Model_KIGHANERENDEN_DK1_2061.0',
#        'Novana_Model_KIGHANERENDEN_DK1_2492.0',
#        'Novana_Model_KIGHANERENDEN_DK1_2923.0',
#        'Novana_Model_KIGHANERENDEN_DK1_3100.0',
#        'Novana_Model_KIGHANERENDEN_DK1_3436.0',
#        'Novana_Model_KIGHANERENDEN_DK1_3772.0',
#        'Novana_Model_KIGHANERENDEN_DK1_4108.0',
#        'Novana_Model_KIGHANERENDEN_DK1_4394.0',
#        'Novana_Model_KIGHANERENDEN_DK1_4680.0',
#        'Novana_Model_KIGHANERENDEN_DK1_5050.0',
#        'Novana_Model_KIGHANERENDEN_DK1_5413.0',
#        'Novana_Model_KIGHANERENDEN_DK1_5776.0',
#        'DK2013_Vejlesoe_Kanal_DK1_0.0',
#        'DK2013_Vejlesoe_Kanal_DK1_467.833',
#        'DK2013_Vejlesoe_Kanal_DK1_935.667',
#        'DK2013_Vejlesoe_Kanal_DK1_1403.5',
#        'DK2013_Vejlesoe_Kanal_DK1_1871.333',
#        'DK2013_Vejlesoe_Kanal_DK1_2339.167',
#        'DK2013_Vejlesoe_Kanal_DK1_2807.0',
#        'DK2013_Vejlesoe_Kanal_DK1_3274.833',
#        'DK2013_Vejlesoe_Kanal_DK1_3742.667',
#        'DK2013_Vejlesoe_Kanal_DK1_4210.5',
#        'DK2013_Vejlesoe_Kanal_DK1_4678.333',
#        'DK2013_Vejlesoe_Kanal_DK1_5146.167',
#        'DK2013_Vejlesoe_Kanal_DK1_5614.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_0.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_433.3333333333333',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_866.6666666666666',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_1300.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_1733.3333333333333',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_2166.6666666666665',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_2600.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_3040.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_3480.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_3920.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_4360.0',
#        'Novana_Model_VASSINGROEDLOEBET_DK1_4800.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_974.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_1333.5',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_1693.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_2058.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_2423.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_2905.5',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_3388.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_3769.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_4150.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_4586.0',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_4586.0_Downstream',
#        'Novana_Model_MAGLEMOSERENDEN_DK1_4781.0',
#        'DK2013_3764969_a_DK1_0.0', 'DK2013_3764969_a_DK1_416.0',
#        'DK2013_Afloeb_fra_skovroedsoe_DK1_0.0',
#        'DK2013_Afloeb_fra_skovroedsoe_DK1_494.0',
#        'DK2013_Afloeb_fra_skovroedsoe_DK1_988.0',
#        'DK2013_Afloeb_fra_skovroedsoe_DK1_1482.0',
#        'DK2013_Afloeb_fra_skovroedsoe_DK1_1976.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_0.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_20.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_300.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_600.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_837.5',
#        'Novana_Model_BAGSVAERD_SOE_DK1_846.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_846.0_Downstream',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1075.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1265.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1455.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1582.5',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1710.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1822.5',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1915.0',
#        'Novana_Model_BAGSVAERD_SOE_DK1_1935.0',
#        'Novana_Model_BRANCH_82_DK1_0.0',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_0.0',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_398.5',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_797.0',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_1166.25',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_1535.5',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_1732.509464498751',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_1732.509464498751_Downstream',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_2003.2547322493756',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_2274.0',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_2617.5',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_2961.0',
#        'Novana_Model_DUMPEDALSRENDEN_DK1_3011.0',
#        'Novana_Model_BASTRUP_SOE_DK1_0.0',
#        'Novana_Model_BASTRUP_SOE_DK1_20.0',
#        'Novana_Model_BASTRUP_SOE_DK1_220.0',
#        'Novana_Model_BASTRUP_SOE_DK1_440.0',
#        'Novana_Model_BASTRUP_SOE_DK1_650.0',
#        'Novana_Model_BASTRUP_SOE_DK1_860.0',
#        'Novana_Model_BASTRUP_SOE_DK1_970.0',
#        'Novana_Model_BASTRUP_SOE_DK1_1080.0',
#        'Novana_Model_BASTRUP_SOE_DK1_1160.0',
#        'Novana_Model_BASTRUP_SOE_DK1_1240.0',
#        'Novana_Model_BASTRUP_SOE_DK1_1332.5',
#        'Novana_Model_BASTRUP_SOE_DK1_1405.0',
#        'Novana_Model_BASTRUP_SOE_DK1_1425.0', 'DK2013_3794565_DK1_0.0',
#        'DK2013_3794565_DK1_354.667', 'DK2013_3794565_DK1_709.333',
#        'DK2013_3794565_DK1_1064.0', 'DK2013_3764969_b_DK1_0.0',
#        'DK2013_3764969_b_DK1_354.333', 'DK2013_3764969_b_DK1_708.667',
#        'DK2013_3764969_b_DK1_1063.0',
#        'DK2013_Tilloeb_til_MoelleAa_11_DK1_0.0',
#        'DK2013_Tilloeb_til_MoelleAa_11_DK1_473.0',
#        'DK2013_Tilloeb_til_MoelleAa_11_DK1_946.0'], dtype=object)

# %%
distances.head(5)
# Out:
#      Xgeometry     Ygeometry  Zgeometry  \
# 0  720048.2482  6.189499e+06        NaN
# 1  719246.9998  6.187692e+06        NaN
# 2  723089.9998  6.190139e+06        NaN
# 3  719222.9998  6.187787e+06        NaN
# 4  719485.9998  6.186962e+06        NaN
#
#                                          Navn  Reduceret  Bassinvolu  \
# 0  Afledning til Lyngby-Taarnbæks ledningsnet   0.732107           0
# 1                                       Ly R6   9.000000         230
# 2                                       Rå R2   1.390000           0
# 3                                       Ly R4  14.240000         255
# 4                                      Ly R10  18.140000        1150
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 0  Overløbsbygværk uden bassin         OV       Rudersdal kommune
# 1   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 2  Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 3   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 4   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                            Ejer                Idriftsat  \
# 0     Novafos Vand Rudersdal A/S (CVR 32940048)  1900/01/01 00:00:00.000
# 1  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 2  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 3  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 4  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#   Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 0  Aktivt           0         NaN         0
# 1  Aktivt        2348         NaN       423
# 2  Aktivt           0         NaN         0
# 3  Aktivt        9734         NaN      1752
# 4  Aktivt        4745         NaN       854
#
#    Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 0                                      0           0    0.000000
# 1                                     70          28    4.696897
# 2                                      0           0    0.000000
# 3                                    292         117   19.468060
# 4                                    142          57    9.489580
#
#                              HubName   HubDist
# 0   Novana_Model_MOELLEAA_DK1_8070.0  0.075449
# 1   Novana_Model_MOELLEAA_DK1_5450.0  0.040376
# 2  Novana_Model_MOELLEAA_DK1_11690.0  0.054776
# 3   Novana_Model_MOELLEAA_DK1_5450.0  0.131985
# 4   Novana_Model_MOELLEAA_DK1_4657.0  0.048889

# %%
# Filter rows where 'registreringfra' contains either 'Novana_Model_MOELLEAA_DK1_13500' or 'Novana_Model_MOELLEAA_DK1_3687'
idxMoelleAA = riverNodes['beregningspunktlokalid'].str.contains('MOELLEAA')

# %%
riverNodes = riverNodes[idxMoelleAA]
riverNodes = riverNodes.reset_index()
riverNodesYY = riverNodes[riverNodes["aar"]==2011]
riverNodesMM = riverNodesYY[riverNodes["maaned"]=="januar"]
idxUp= riverNodesMM['beregningspunktlokalid'].str.contains('3687')
idxDown= riverNodesMM['beregningspunktlokalid'].str.contains('13500')
#finding the index which corresponds to the inlet
idxUp_num = idxUp.where(idxUp == True).dropna().index
#finding the index which corresponds to the outlet
idxDown_num = idxDown.where(idxDown == True).dropna().index
#trasforming Int64Index type index to an integer to create an array from the index difference
idxUp_num = idxUp_num[0]
idxDown_num = idxDown_num[0]
indexdiff= abs(idxUp_num - idxDown_num)
# Out:
# C:\Users\39333\AppData\Local\Temp/ipykernel_16680/2995376345.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   riverNodesMM = riverNodesYY[riverNodes["maaned"]=="januar"]

# %%
idxUpDown = idxUp

# %%
for i in range(idxUp_num, idxDown_num+1):
    idxUpDown[i] = True

# %%
riverQ = riverNodesMM[idxUpDown]
# Out:
# C:\Users\39333\AppData\Local\Temp/ipykernel_16680/4255848063.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   riverQ = riverNodesMM[idxUpDown]

# %%
riverQ = riverQ[['water flow (m^3/s)', 'beregningspunktlokalid', 'X', 'Y']]

# %%
riverQ.reset_index()
riverQ['distance'] = np.NaN
riverQ['CSOflow'] = np.NaN

# %%
riverC = riverQ[['beregningspunktlokalid', 'X', 'Y', 'distance']]
riverC.reset_index()
EQS_exc= riverC.copy()

# %%
StringName=riverQ['beregningspunktlokalid'].str.split('_').str[-1]
StringName = StringName.astype(float)

# %%
type(StringName)
# Out:
# pandas.core.series.Series

# %%
riverQ["distance"]= StringName - 3687

# %%
riverC['concentration'] = 0

# %%
# starting the simple advection-dilution model 
#riverC[0]= C0 #initial concentration
#CSO_conc= XX # assign the MP concentration in the CSO water

# %%
riverQ["beregningspunktlokalid"].
# Out:
# 'Novana_Model_MOELLEAA_DK1_3687.0'

# %%
distances
# Out:
#       Xgeometry     Ygeometry  Zgeometry  \
# 0   720048.2482  6.189499e+06        NaN
# 1   719246.9998  6.187692e+06        NaN
# 2   723089.9998  6.190139e+06        NaN
# 3   719222.9998  6.187787e+06        NaN
# 4   719485.9998  6.186962e+06        NaN
# 5   721532.9998  6.189676e+06        NaN
# 6   719175.9998  6.187597e+06        NaN
# 7   718976.9998  6.186827e+06        NaN
# 8   719175.9998  6.187597e+06        NaN
# 9   721214.9998  6.189541e+06        NaN
# 10  721671.9458  6.189762e+06        NaN
# 11  719373.9998  6.187144e+06        NaN
# 12  721667.9998  6.189779e+06        NaN
# 13  719266.9998  6.189292e+06        NaN
# 14  719413.9998  6.188747e+06        NaN
# 15  719304.9998  6.189177e+06        NaN
# 16  719238.9998  6.189009e+06        NaN
# 17  719365.9998  6.188216e+06        NaN
# 18  719159.9998  6.189342e+06        NaN
# 19  721652.7824  6.189872e+06        NaN
# 20  719397.9998  6.187160e+06        NaN
# 21  720262.9998  6.189605e+06        NaN
# 22  719460.9998  6.186477e+06        NaN
# 23  719466.9998  6.186489e+06        NaN
# 24  719462.9998  6.186452e+06        NaN
# 25  719921.9998  6.189414e+06        NaN
# 26  719532.9998  6.188240e+06        NaN
#
#                                           Navn   Reduceret  Bassinvolu  \
# 0   Afledning til Lyngby-Taarnbæks ledningsnet    0.732107           0
# 1                                        Ly R6    9.000000         230
# 2                                        Rå R2    1.390000           0
# 3                                        Ly R4   14.240000         255
# 4                                       Ly R10   18.140000        1150
# 5                                      Lu R20F   42.000000         300
# 6                                       Ly R3R    3.010000           0
# 7                                       Ly R39    0.910000          20
# 8                                       Ly R3F         NaN           0
# 9                                       Lu R7F   14.400000          87
# 10                                    OMLU103O   19.967886           0
# 11                                      Ly R12    0.560000           3
# 12                                      Lu R23         NaN           0
# 13                                       Lu R9   20.700000           0
# 14                                     Ly R29F    1.060000         106
# 15                                      Ly R34   20.700000           0
# 16                                      Ly R33    8.870000         320
# 17                                      Ly R46    2.270000          10
# 18                                       Vi R2  124.300000        4681
# 19                                     UF01001   16.127675           0
# 20                                      Ly R8F    2.910000         160
# 21                                      Lu R4F    7.810000         540
# 22                                      Ly R15    1.531850          13
# 23                                      Ly R16  138.700000        2200
# 24                                     Ly R18F  138.700000          13
# 25                                      Lu R5F    7.250000         185
# 26                                     Ly R32F    3.750000          21
#
#                      Udlednings Bygvaerkst              Godkendels  \
# 0   Overløbsbygværk uden bassin         OV       Rudersdal kommune
# 1    Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 2   Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 3    Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 4    Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 5    Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 6   Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 7   Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 8   Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 9    Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 10  Overløbsbygværk uden bassin         OV       Rudersdal kommune
# 11   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 12  Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 13  Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 14   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 15  Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
# 16   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 17   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 18   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 19  Overløbsbygværk uden bassin         OV       Rudersdal kommune
# 20   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 21   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 22   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 23   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 24   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 25   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
# 26   Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                             Ejer                Idriftsat  \
# 0      Novafos Vand Rudersdal A/S (CVR 32940048)  1900/01/01 00:00:00.000
# 1   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 2   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 3   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 4   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 5   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 6   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 7   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 8   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  2021/01/01 00:00:00.000
# 9   LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 10     Novafos Vand Rudersdal A/S (CVR 32940048)  1900/01/01 00:00:00.000
# 11  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 12  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 13  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 14  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 15  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 16  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 17  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 18  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 19     Novafos Vand Rudersdal A/S (CVR 32940048)  1900/01/01 00:00:00.000
# 20  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 21  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 22  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 23  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 24  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 25  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
# 26  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#    Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 0   Aktivt           0         NaN         0
# 1   Aktivt        2348         NaN       423
# 2   Aktivt           0         NaN         0
# 3   Aktivt        9734         NaN      1752
# 4   Aktivt        4745         NaN       854
# 5   Aktivt       24202         NaN      4356
# 6   Aktivt       13529         NaN      2435
# 7   Aktivt           0         NaN         0
# 8   Aktivt         126         NaN        23
# 9   Aktivt        3584         NaN       645
# 10  Aktivt           0         0.0         0
# 11  Aktivt           0         NaN         0
# 12  Aktivt           0         NaN         0
# 13  Aktivt       22632         NaN      4074
# 14  Aktivt           0         NaN         0
# 15  Aktivt         178         NaN        32
# 16  Aktivt        4963         NaN       893
# 17  Aktivt           0         NaN         0
# 18  Aktivt       80193         NaN     14435
# 19  Aktivt       14006         7.0      2521
# 20  Aktivt           0         NaN         0
# 21  Aktivt           0         NaN         0
# 22  Aktivt        2017         NaN       363
# 23  Aktivt      105411         NaN     18974
# 24  Aktivt        1998         NaN       360
# 25  Aktivt           0         NaN         0
# 26  Aktivt           0         NaN         0
#
#     Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 0                                       0           0    0.000000
# 1                                      70          28    4.696897
# 2                                       0           0    0.000000
# 3                                     292         117   19.468060
# 4                                     142          57    9.489580
# 5                                     726         290   48.404137
# 6                                     406         162   27.057372
# 7                                       0           0    0.000000
# 8                                       4           2    0.252630
# 9                                     108          43    7.168789
# 10                                      0           0    0.000000
# 11                                      0           0    0.000000
# 12                                      0           0    0.000000
# 13                                    679         272   45.264000
# 14                                      0           0    0.000000
# 15                                      5           2    0.355113
# 16                                    149          60    9.925147
# 17                                      0           0    0.000000
# 18                                   2406         962  160.386100
# 19                                    419         168   27.681013
# 20                                      0           0    0.000000
# 21                                      0           0    0.000000
# 22                                     61          24    4.033565
# 23                                   3162        1265  210.822590
# 24                                     60          24    3.996631
# 25                                      0           0    0.000000
# 26                                      0           0    0.000000
#
#                               HubName   HubDist
# 0    Novana_Model_MOELLEAA_DK1_8070.0  0.075449
# 1    Novana_Model_MOELLEAA_DK1_5450.0  0.040376
# 2   Novana_Model_MOELLEAA_DK1_11690.0  0.054776
# 3    Novana_Model_MOELLEAA_DK1_5450.0  0.131985
# 4    Novana_Model_MOELLEAA_DK1_4657.0  0.048889
# 5    Novana_Model_MOELLEAA_DK1_9685.0  0.134917
# 6    Novana_Model_MOELLEAA_DK1_5316.0  0.066445
# 7    Novana_Model_MOELLEAA_DK1_3525.5  0.286607
# 8    Novana_Model_MOELLEAA_DK1_5316.0  0.066445
# 9    Novana_Model_MOELLEAA_DK1_9374.0  0.193031
# 10  Novana_Model_MOELLEAA_DK1_10023.0  0.101586
# 11   Novana_Model_MOELLEAA_DK1_4657.0  0.165663
# 12  Novana_Model_MOELLEAA_DK1_10023.0  0.101726
# 13   Novana_Model_MOELLEAA_DK1_7124.0  0.171120
# 14   Novana_Model_MOELLEAA_DK1_6679.0  0.055037
# 15   Novana_Model_MOELLEAA_DK1_7124.0  0.055124
# 16   Novana_Model_MOELLEAA_DK1_6969.0  0.122464
# 17   Novana_Model_MOELLEAA_DK1_6146.0  0.079731
# 18   Novana_Model_MOELLEAA_DK1_7124.0  0.274429
# 19  Novana_Model_MOELLEAA_DK1_10023.0  0.140433
# 20   Novana_Model_MOELLEAA_DK1_4657.0  0.170570
# 21   Novana_Model_MOELLEAA_DK1_8300.0  0.031320
# 22   Novana_Model_MOELLEAA_DK1_4083.0  0.022788
# 23   Novana_Model_MOELLEAA_DK1_4083.0  0.025445
# 24   Novana_Model_MOELLEAA_DK1_4083.0  0.042659
# 25   Novana_Model_MOELLEAA_DK1_7828.0  0.043352
# 26   Novana_Model_MOELLEAA_DK1_6146.0  0.099509

# %%
distances["HubName"]
# Out:
# 0      Novana_Model_MOELLEAA_DK1_8070.0
# 1      Novana_Model_MOELLEAA_DK1_5450.0
# 2     Novana_Model_MOELLEAA_DK1_11690.0
# 3      Novana_Model_MOELLEAA_DK1_5450.0
# 4      Novana_Model_MOELLEAA_DK1_4657.0
# 5      Novana_Model_MOELLEAA_DK1_9685.0
# 6      Novana_Model_MOELLEAA_DK1_5316.0
# 7      Novana_Model_MOELLEAA_DK1_3525.5
# 8      Novana_Model_MOELLEAA_DK1_5316.0
# 9      Novana_Model_MOELLEAA_DK1_9374.0
# 10    Novana_Model_MOELLEAA_DK1_10023.0
# 11     Novana_Model_MOELLEAA_DK1_4657.0
# 12    Novana_Model_MOELLEAA_DK1_10023.0
# 13     Novana_Model_MOELLEAA_DK1_7124.0
# 14     Novana_Model_MOELLEAA_DK1_6679.0
# 15     Novana_Model_MOELLEAA_DK1_7124.0
# 16     Novana_Model_MOELLEAA_DK1_6969.0
# 17     Novana_Model_MOELLEAA_DK1_6146.0
# 18     Novana_Model_MOELLEAA_DK1_7124.0
# 19    Novana_Model_MOELLEAA_DK1_10023.0
# 20     Novana_Model_MOELLEAA_DK1_4657.0
# 21     Novana_Model_MOELLEAA_DK1_8300.0
# 22     Novana_Model_MOELLEAA_DK1_4083.0
# 23     Novana_Model_MOELLEAA_DK1_4083.0
# 24     Novana_Model_MOELLEAA_DK1_4083.0
# 25     Novana_Model_MOELLEAA_DK1_7828.0
# 26     Novana_Model_MOELLEAA_DK1_6146.0
# Name: HubName, dtype: object

# %%
distances["HubName"].str.contains(riverQ["beregningspunktlokalid"].iloc[i]).sum()
# Out:
# 0

# %%
for i in range(len(riverQ)):
    csoBool = distances["HubName"].str.contains(riverQ["beregningspunktlokalid"].iloc[i])
    isThereCSO = csoBool.sum() == 1 # check if there is a CSO
    if isThereCSO:
        idxCSO = csoBool[csoBool == True].index
        #print(distances.iloc[idxCSO])
        CSO_flux=0 #create an empty value for the MP flux from the CSO
        CSO_Qtot=0 #create an empty value for the total CSO flow added to the river
        for j in range(len(idxCSO)) #loop over the connected CSOs
            V_CSO= distances["Vandmaengd"][idxCSO[j]]*theta # calculate the volume of the single discharge event
            Q_CSO=V_CSO/t_CSO # calculate the flow of the single discharge event
            
            CSO_flux=CSO_flux+Q_CSO*CSO_conc
            CSO_Qtot= CSO_Qtot+Q_CSO
            riverQ['Qadded'][i]= riverQ['Qadded'][i-1]+CSO_Qtot
            # calculate concentration for the node
            riverC['conc'][i]=(riverC['conc'][i-1]*(riverQ['flow'][i-1]+
            riverQ['Qadded'][i-1])+ CSO_flux)/ (riverQ['flow'][i]+
            riverQ['Qadded'][i])
    else: # there are no CSO connected to the node
        # calculate flow added to the river by the CSO (no addition)
        riverQ['Qadded'][i]= riverQ['Qadded'][i-1]
        # calculate concentration for the node
        riverC['conc'][i] =riverC['conc'][i-1]*(riverQ['flow'][i-1]+
        riverQ['Qadded'][i-1])/ (riverQ['flow'][i]+
        riverQ['Qadded'][i])
   
EQS_exc= riverC["conc"]>EQS_exc
# Out:
#       Xgeometry     Ygeometry  Zgeometry     Navn  Reduceret  Bassinvolu  \
# 14  719413.9998  6.188747e+06        NaN  Ly R29F       1.06         106
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 14  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                             Ejer                Idriftsat  \
# 14  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#    Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 14  Aktivt           0         NaN         0
#
#     Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 14                                      0           0         0.0
#
#                              HubName   HubDist
# 14  Novana_Model_MOELLEAA_DK1_6679.0  0.055037
#       Xgeometry     Ygeometry  Zgeometry    Navn  Reduceret  Bassinvolu  \
# 16  719238.9998  6.189009e+06        NaN  Ly R33       8.87         320
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 16  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                             Ejer                Idriftsat  \
# 16  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#    Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 16  Aktivt        4963         NaN       893
#
#     Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 16                                    149          60    9.925147
#
#                              HubName   HubDist
# 16  Novana_Model_MOELLEAA_DK1_6969.0  0.122464
#       Xgeometry     Ygeometry  Zgeometry    Navn  Reduceret  Bassinvolu  \
# 25  719921.9998  6.189414e+06        NaN  Lu R5F       7.25         185
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 25  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                             Ejer                Idriftsat  \
# 25  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#    Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 25  Aktivt           0         NaN         0
#
#     Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 25                                      0           0         0.0
#
#                              HubName   HubDist
# 25  Novana_Model_MOELLEAA_DK1_7828.0  0.043352
#      Xgeometry     Ygeometry  Zgeometry  \
# 0  720048.2482  6.189499e+06        NaN
#
#                                          Navn  Reduceret  Bassinvolu  \
# 0  Afledning til Lyngby-Taarnbæks ledningsnet   0.732107           0
#
#                     Udlednings Bygvaerkst         Godkendels  \
# 0  Overløbsbygværk uden bassin         OV  Rudersdal kommune
#
#                                         Ejer                Idriftsat Nedlagt  \
# 0  Novafos Vand Rudersdal A/S (CVR 32940048)  1900/01/01 00:00:00.000  Aktivt
#
#    Vandmaengd  Antal over  COD (kg)  Biological oxygen demand, 5 days (kg)  \
# 0           0         NaN         0                                      0
#
#    Total-N (k  Total-P (k                           HubName   HubDist
# 0           0         0.0  Novana_Model_MOELLEAA_DK1_8070.0  0.075449
#       Xgeometry     Ygeometry  Zgeometry    Navn  Reduceret  Bassinvolu  \
# 21  720262.9998  6.189605e+06        NaN  Lu R4F       7.81         540
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 21  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                             Ejer                Idriftsat  \
# 21  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#    Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 21  Aktivt           0         NaN         0
#
#     Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 21                                      0           0         0.0
#
#                              HubName  HubDist
# 21  Novana_Model_MOELLEAA_DK1_8300.0  0.03132
#      Xgeometry     Ygeometry  Zgeometry    Navn  Reduceret  Bassinvolu  \
# 9  721214.9998  6.189541e+06        NaN  Lu R7F       14.4          87
#
#                    Udlednings Bygvaerkst              Godkendels  \
# 9  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                            Ejer                Idriftsat  \
# 9  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#   Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 9  Aktivt        3584         NaN       645
#
#    Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 9                                    108          43    7.168789
#
#                             HubName   HubDist
# 9  Novana_Model_MOELLEAA_DK1_9374.0  0.193031
#      Xgeometry     Ygeometry  Zgeometry     Navn  Reduceret  Bassinvolu  \
# 5  721532.9998  6.189676e+06        NaN  Lu R20F       42.0         300
#
#                    Udlednings Bygvaerkst              Godkendels  \
# 5  Overløbsbygværk med bassin         OS  LYNGBY-TAARBÆK KOMMUNE
#
#                                            Ejer                Idriftsat  \
# 5  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#   Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 5  Aktivt       24202         NaN      4356
#
#    Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 5                                    726         290   48.404137
#
#                             HubName   HubDist
# 5  Novana_Model_MOELLEAA_DK1_9685.0  0.134917
#      Xgeometry     Ygeometry  Zgeometry   Navn  Reduceret  Bassinvolu  \
# 2  723089.9998  6.190139e+06        NaN  Rå R2       1.39           0
#
#                     Udlednings Bygvaerkst              Godkendels  \
# 2  Overløbsbygværk uden bassin         OV  LYNGBY-TAARBÆK KOMMUNE
#
#                                            Ejer                Idriftsat  \
# 2  LYNGBY-TAARBÆK SPILDEVAND A/S (CVR 32292771)  1900/01/01 00:00:00.000
#
#   Nedlagt  Vandmaengd  Antal over  COD (kg)  \
# 2  Aktivt           0         NaN         0
#
#    Biological oxygen demand, 5 days (kg)  Total-N (k  Total-P (k  \
# 2                                      0           0         0.0
#
#                              HubName   HubDist
# 2  Novana_Model_MOELLEAA_DK1_11690.0  0.054776
